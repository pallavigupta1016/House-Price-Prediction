# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
dataset=pd.read_csv("train.csv")
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(dataset,dataset['SalePrice'],test_size=0.1,random_state=0)

# %%
X_train.shape,X_test.shape
# Out:
# ((1314, 81), (146, 81))

# %%
#finding NaN values in categorical features

features_na=[features for features in dataset.columns if dataset[features].isnull().sum()>1 and dataset[features].dtypes=='O']

for feature in features_na:
  print('There are {}% missing values in {}'.format(np.round(dataset[feature].isnull().mean(),4),feature))
# Out:
# There are 0.9377% missing values in Alley
# There are 0.0055% missing values in MasVnrType
# There are 0.0253% missing values in BsmtQual
# There are 0.0253% missing values in BsmtCond
# There are 0.026% missing values in BsmtExposure
# There are 0.0253% missing values in BsmtFinType1
# There are 0.026% missing values in BsmtFinType2
# There are 0.4726% missing values in FireplaceQu
# There are 0.0555% missing values in GarageType
# There are 0.0555% missing values in GarageFinish
# There are 0.0555% missing values in GarageQual
# There are 0.0555% missing values in GarageCond
# There are 0.9952% missing values in PoolQC
# There are 0.8075% missing values in Fence
# There are 0.963% missing values in MiscFeature

# %%
#replace nan values with other label

def replace_cat_features(dataset,features_na):
  data=dataset.copy()
  data[features_na]=data[features_na].fillna('missing')
  return data

dataset=replace_cat_features(dataset,features_na)
dataset[features_na].isnull().sum()
# Out:
# Alley           0
# MasVnrType      0
# BsmtQual        0
# BsmtCond        0
# BsmtExposure    0
# BsmtFinType1    0
# BsmtFinType2    0
# FireplaceQu     0
# GarageType      0
# GarageFinish    0
# GarageQual      0
# GarageCond      0
# PoolQC          0
# Fence           0
# MiscFeature     0
# dtype: int64

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  ...  SaleType  SaleCondition SalePrice
# 0   1          60       RL  ...        WD         Normal    208500
# 1   2          20       RL  ...        WD         Normal    181500
# 2   3          60       RL  ...        WD         Normal    223500
# 3   4          70       RL  ...        WD        Abnorml    140000
# 4   5          60       RL  ...        WD         Normal    250000
#
# [5 rows x 81 columns]

# %%
#finding nan values in numerical features

numerical_na=[features for features in dataset.columns if dataset[features].isnull().sum()>1 and dataset[features].dtypes!='O']

for feature in numerical_na:
  print('{}:{}% is missing'.format(feature,np.round(dataset[feature].isnull().mean(),4)))
# Out:
# LotFrontage:0.1774% is missing
# MasVnrArea:0.0055% is missing
# GarageYrBlt:0.0555% is missing

# %%
#replacing numerical nan values with median value
for feature in numerical_na:
  median_value=dataset[feature].median()
  print('{}:median value={}'.format(feature,median_value))
  #create a new feature to capture nan values
  dataset[feature+'nan']=np.where(dataset[feature].isnull(),1,0)
  dataset[feature].fillna(median_value,inplace=True)
  
dataset[numerical_na].isnull().sum()
# Out:
# LotFrontage:median value=69.0
# MasVnrArea:median value=0.0
# GarageYrBlt:median value=1980.0
# LotFrontage    0
# MasVnrArea     0
# GarageYrBlt    0
# dtype: int64

# %%
dataset.head(50)
# Out:
#     Id  MSSubClass MSZoning  ...  LotFrontagenan  MasVnrAreanan GarageYrBltnan
# 0    1          60       RL  ...               0              0              0
# 1    2          20       RL  ...               0              0              0
# 2    3          60       RL  ...               0              0              0
# 3    4          70       RL  ...               0              0              0
# 4    5          60       RL  ...               0              0              0
# 5    6          50       RL  ...               0              0              0
# 6    7          20       RL  ...               0              0              0
# 7    8          60       RL  ...               1              0              0
# 8    9          50       RM  ...               0              0              0
# 9   10         190       RL  ...               0              0              0
# 10  11          20       RL  ...               0              0              0
# ...

# %%
#temporal variables

for feature in ['YearBuilt','YearRemodAdd','GarageYrBlt']:
  dataset[feature]=dataset['YrSold']-dataset[feature]

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  ...  LotFrontagenan  MasVnrAreanan GarageYrBltnan
# 0   1          60       RL  ...               0              0              0
# 1   2          20       RL  ...               0              0              0
# 2   3          60       RL  ...               0              0              0
# 3   4          70       RL  ...               0              0              0
# 4   5          60       RL  ...               0              0              0
#
# [5 rows x 84 columns]

# %%
dataset[['YearBuilt','YearRemodAdd','GarageYrBlt']].head()
# Out:
#    YearBuilt  YearRemodAdd  GarageYrBlt
# 0          5             5          5.0
# 1         31            31         31.0
# 2          7             6          7.0
# 3         91            36          8.0
# 4          8             8          8.0

# %% [markdown]
# # Numerical features

# %%
#since numerical features is skewed we'll perform log normal distribution

num_features=['LotFrontage','LotArea','1stFlrSF','GrLivArea','SalePrice']
for feature in num_features:
  dataset[feature]=np.log(dataset[feature])

# %%
dataset.head()
# Out:
#    Id  MSSubClass MSZoning  ...  LotFrontagenan  MasVnrAreanan GarageYrBltnan
# 0   1          60       RL  ...               0              0              0
# 1   2          20       RL  ...               0              0              0
# 2   3          60       RL  ...               0              0              0
# 3   4          70       RL  ...               0              0              0
# 4   5          60       RL  ...               0              0              0
#
# [5 rows x 84 columns]

# %% [markdown]
# # Handling rare categorical features

# %%
categorical_features=[feature for feature in dataset.columns if dataset[feature].dtypes=='O']

for feature in categorical_features:
  temp=dataset.groupby(feature)['SalePrice'].count()/len(dataset)
  temp_df=temp[temp>0.01].index
  dataset[feature]=np.where(dataset[feature].isin(temp_df),dataset[feature],'rare_var')

# %%
dataset.head(50)
# Out:
#     Id  MSSubClass  MSZoning  ...  LotFrontagenan  MasVnrAreanan GarageYrBltnan
# 0    1          60        RL  ...               0              0              0
# 1    2          20        RL  ...               0              0              0
# 2    3          60        RL  ...               0              0              0
# 3    4          70        RL  ...               0              0              0
# 4    5          60        RL  ...               0              0              0
# 5    6          50        RL  ...               0              0              0
# 6    7          20        RL  ...               0              0              0
# 7    8          60        RL  ...               1              0              0
# 8    9          50        RM  ...               0              0              0
# 9   10         190        RL  ...               0              0              0
# 10  11          20        RL  ...               0              0              0
# ...

# %%
for feature in categorical_features:
  label_order=dataset.groupby(feature)['SalePrice'].mean().sort_values().index
  label_order={k:i for i,k in enumerate(label_order,0)}
  dataset[feature]=dataset[feature].map(label_order)

# %%
dataset.head(10)
# Out:
#    Id  MSSubClass  MSZoning  ...  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# 0   1          60         3  ...               0              0               0
# 1   2          20         3  ...               0              0               0
# 2   3          60         3  ...               0              0               0
# 3   4          70         3  ...               0              0               0
# 4   5          60         3  ...               0              0               0
# 5   6          50         3  ...               0              0               0
# 6   7          20         3  ...               0              0               0
# 7   8          60         3  ...               1              0               0
# 8   9          50         1  ...               0              0               0
# 9  10         190         3  ...               0              0               0
#
# [10 rows x 84 columns]

# %%
scaling_feature=[feature for feature in dataset.columns if feature not in ['Id','SalePrice']]
len(scaling_feature)
# Out:
# 82

# %%
scaling_feature
# Out:
# ['MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'MasVnrType',
#  'MasVnrArea',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'BsmtQual',
#  'BsmtCond',
#  'BsmtExposure',
#  'BsmtFinType1',
#  'BsmtFinSF1',
#  'BsmtFinType2',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'Electrical',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'KitchenQual',
#  'TotRmsAbvGrd',
#  'Functional',
#  'Fireplaces',
#  'FireplaceQu',
#  'GarageType',
#  'GarageYrBlt',
# ...

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
scaler.fit(dataset[scaling_feature])
# Out:
# MinMaxScaler(copy=True, feature_range=(0, 1))

# %%
scaler.transform(dataset[scaling_feature])
# Out:
# array([[0.23529412, 0.75      , 0.41820812, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.49506375, ..., 0.        , 0.        ,
#         0.        ],
#        [0.23529412, 0.75      , 0.434909  , ..., 0.        , 0.        ,
#         0.        ],
#        ...,
#        [0.29411765, 0.75      , 0.42385922, ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.434909  , ..., 0.        , 0.        ,
#         0.        ],
#        [0.        , 0.75      , 0.47117546, ..., 0.        , 0.        ,
#         0.        ]])

# %%
# transform the train and test set, and add on the Id and SalePrice variables
data = pd.concat([dataset[['Id', 'SalePrice']].reset_index(drop=True),
                    pd.DataFrame(scaler.transform(dataset[scaling_feature]), columns=scaling_feature)],
                    axis=1)

# %%
data.head()
# Out:
#    Id  SalePrice  MSSubClass  ...  LotFrontagenan  MasVnrAreanan  GarageYrBltnan
# 0   1  12.247694    0.235294  ...             0.0            0.0             0.0
# 1   2  12.109011    0.000000  ...             0.0            0.0             0.0
# 2   3  12.317167    0.235294  ...             0.0            0.0             0.0
# 3   4  11.849398    0.294118  ...             0.0            0.0             0.0
# 4   5  12.429216    0.235294  ...             0.0            0.0             0.0
#
# [5 rows x 84 columns]

# %%
data.to_csv('X_train.csv',index=False)
